# %%
from collections import Counter

with open("corpus.txt", "r") as file:
    words = file.read().splitlines()

words = [word.lower().strip() for word in words if word.strip()]

vocab = Counter()

for word in words:
    token = " ".join(list(word)) + " </w>"
    vocab[token] += 1

print("Initial Vocabulary\n")

for word, freq in vocab.items():
    print(f"{word} : {freq}")

def count_pairs(vocabulary):

    pairs = Counter()

    for word, freq in vocabulary.items():

        symbols = word.split()

        for i in range(len(symbols)-1):
            pairs[(symbols[i], symbols[i+1])] += freq

    return pairs


def merge_pair(pair, vocabulary):

    first, second = pair
    new_vocab = {}

    for word, freq in vocabulary.items():

        symbols = word.split()

        merged = []

        i = 0

        while i < len(symbols):

            if (
                i < len(symbols)-1
                and symbols[i] == first
                and symbols[i+1] == second
            ):

                merged.append(first + second)
                i += 2

            else:

                merged.append(symbols[i])
                i += 1

        new_vocab[" ".join(merged)] = freq

    return Counter(new_vocab)


merge_rules = []

num_merges = 10

for step in range(num_merges):

    print("\n==============================")
    print("Merge", step + 1)

    pairs = count_pairs(vocab)

    if len(pairs) == 0:
        break

    best_pair = pairs.most_common(1)[0][0]

    print("Most Frequent Pair:", best_pair)
    print("Frequency:", pairs[best_pair])

    merge_rules.append(best_pair)

    vocab = merge_pair(best_pair, vocab)

    print("\nVocabulary After Merge")

    for word in vocab:
        print(word)

final_vocab = set()

for word in vocab:
    final_vocab.update(word.split())


def encode(word, merge_rules):

    tokens = list(word.lower()) + ["</w>"]

    for first, second in merge_rules:

        merged = []

        i = 0

        while i < len(tokens):

            if (
                i < len(tokens)-1
                and tokens[i] == first
                and tokens[i+1] == second
            ):

                merged.append(first + second)
                i += 2

            else:

                merged.append(tokens[i])
                i += 1

        tokens = merged

    return tokens



def decode(tokens):

    word = "".join(tokens)

    return word.replace("</w>", "")

test_word = "playing"

encoded = encode(test_word, merge_rules)

decoded = decode(encoded)

print("\n==============================")
print("Merge Rules")

for i, rule in enumerate(merge_rules, start=1):
    print(f"{i}. {rule}")

print("\nFinal Vocabulary")

print(sorted(final_vocab))

print("\nVocabulary Size:", len(final_vocab))

print("\nTest Word")

print("Original :", test_word)

print("Encoded  :", encoded)

print("Decoded  :", decoded)
# Out:
# Initial Vocabulary
#
# p l a y i n g </w> : 2
# p l a y e d </w> : 1
# p l a y e r </w> : 1
# p l a y f u l </w> : 1
# r e p l a y i n g </w> : 1
#
# ==============================
# Merge 1
# Most Frequent Pair: ('p', 'l')
# Frequency: 6
#
# Vocabulary After Merge
# pl a y i n g </w>
# pl a y e d </w>
# pl a y e r </w>
# pl a y f u l </w>
# r e pl a y i n g </w>
#
# ==============================
# Merge 2
# Most Frequent Pair: ('pl', 'a')
# Frequency: 6
#
# Vocabulary After Merge
# pla y i n g </w>
# pla y e d </w>
# pla y e r </w>
# pla y f u l </w>
# r e pla y i n g </w>
#
# ==============================
# Merge 3
# Most Frequent Pair: ('pla', 'y')
# Frequency: 6
#
# Vocabulary After Merge
# play i n g </w>
# play e d </w>
# play e r </w>
# play f u l </w>
# r e play i n g </w>
#
# ==============================
# Merge 4
# Most Frequent Pair: ('play', 'i')
# Frequency: 3
#
# Vocabulary After Merge
# playi n g </w>
# play e d </w>
# play e r </w>
# play f u l </w>
# r e playi n g </w>
#
# ==============================
# Merge 5
# Most Frequent Pair: ('playi', 'n')
# Frequency: 3
#
# Vocabulary After Merge
# playin g </w>
# play e d </w>
# play e r </w>
# play f u l </w>
# r e playin g </w>
#
# ==============================
# Merge 6
# Most Frequent Pair: ('playin', 'g')
# Frequency: 3
#
# Vocabulary After Merge
# playing </w>
# play e d </w>
# play e r </w>
# play f u l </w>
# r e playing </w>
#
# ==============================
# Merge 7
# Most Frequent Pair: ('playing', '</w>')
# Frequency: 3
#
# Vocabulary After Merge
# playing</w>
# play e d </w>
# play e r </w>
# play f u l </w>
# r e playing</w>
#
# ==============================
# Merge 8
# Most Frequent Pair: ('play', 'e')
# Frequency: 2
#
# Vocabulary After Merge
# playing</w>
# playe d </w>
# playe r </w>
# play f u l </w>
# r e playing</w>
#
# ==============================
# Merge 9
# Most Frequent Pair: ('playe', 'd')
# Frequency: 1
#
# Vocabulary After Merge
# playing</w>
# played </w>
# playe r </w>
# play f u l </w>
# r e playing</w>
#
# ==============================
# Merge 10
# Most Frequent Pair: ('played', '</w>')
# Frequency: 1
#
# Vocabulary After Merge
# playing</w>
# played</w>
# playe r </w>
# play f u l </w>
# r e playing</w>
#
# ==============================
# Merge Rules
# 1. ('p', 'l')
# 2. ('pl', 'a')
# 3. ('pla', 'y')
# 4. ('play', 'i')
# 5. ('playi', 'n')
# 6. ('playin', 'g')
# 7. ('playing', '</w>')
# 8. ('play', 'e')
# 9. ('playe', 'd')
# 10. ('played', '</w>')
#
# Final Vocabulary
# ['</w>', 'e', 'f', 'l', 'play', 'playe', 'played</w>', 'playing</w>', 'r', 'u']
#
# Vocabulary Size: 10
#
# Test Word
# Original : playing
# Encoded  : ['playing</w>']
# Decoded  : playing
